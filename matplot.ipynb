# %% [markdown]
# # MATPLOTLIB

# %%
pip install matplotlib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# ## Line plot

# %%
# height of 10 students
Height= [140,155,160,164,168, 170, 173, 175,174,168]

# %%
# to draw a line graph - plt.plot()
plt.plot(Height)

# %%
# sales of a week
Units_Sold= [25, 40, 45, 50, 40, 25, 55]
Product= ['Product A', 'Product B', 'Product D', 'Product E', 'Product F', 'Product G', 'Product H']

# %%
# plt.plot(x axis, y axis)
plt.plot(Product,Units_Sold)

# %%
# don't show the graph details, warning . just show the graph - plt.show(). put in this last of code
plt.plot(Product,Units_Sold)
plt.show()

# %%
# method 2
plt.plot(Height);

# %% [markdown]
# ## customizing plot

# %% [markdown]
# ### marker
#
# '*' - star
#
# 'o' - round
#
# 's' - square
#
# 'd' - diamond

# %%
plt.plot(Product,Units_Sold,marker='*')
plt.show()

# %%
plt.plot(Product,Units_Sold,marker='o')
plt.show()

# %%
plt.plot(Product,Units_Sold,marker='d')
plt.show()

# %%
plt.plot(Product,Units_Sold,marker='s')
plt.show()

# %% [markdown]
# ## customizing color
#
# ### color='color name' / c='color name'
#
# default color codes
# * r - red
# * g - green
# * b - blue

# %%
plt.plot(Product,Units_Sold,marker='o',color='r')
plt.show()

# %%
plt.plot(Product,Units_Sold,marker='s',c='g')
plt.show()

# %%
plt.plot(Product,Units_Sold,marker='o',color='skyblue')
plt.show()

# %%
plt.plot(Product,Units_Sold,marker='o',color='b')
plt.show()

# %%
plt.plot(Product,Units_Sold,marker='o',color='orange')
plt.show()

# %%
plt.plot(Product,Units_Sold,marker='o',color='yellow')
plt.show()

# %%
plt.plot(Product,Units_Sold,marker='o',color='#40bf40')
plt.show()

# %% [markdown]
# ## customizing labels

# %%
plt.plot(Product,Units_Sold,marker='o',color='black')
plt.xlabel('products')
plt.ylabel('sales')
plt.show()

# %% [markdown]
# ## customizing value arrangements

# %%
plt.plot(Product,Units_Sold,marker='o',c='b')
plt.xlabel('products')
plt.xticks(rotation=90)
plt.ylabel('sales')
plt.show()

# %% [markdown]
# ## customizing title

# %%
plt.plot(Product,Units_Sold,marker='*',c='g')
plt.title('Sales over a week')
plt.xlabel('products')
plt.xticks(rotation=90)
plt.ylabel('sales');

# %% [markdown]
# ## customizing size
#
# on the top of code

# %%
plt.figure(figsize=(10,5))
plt.title('Sales over a week')
plt.xlabel('products')
plt.plot(Product,Units_Sold,marker='*',c='g')
plt.xticks(rotation=90)
plt.ylabel('sales')
plt.show()

# %% [markdown]
# ## comparing two plots

# %%
# sales over a week of company A,B
Units_Sold1= [25, 40, 45, 50, 40, 25, 55]# A
Units_Sold1= [25, 40, 45, 50, 40, 25, 55]# B

# %%
plt.figure(figsize=(10,5))
plt.title('Sales over a week')
plt.xlabel('products')
plt.plot(Product,Units_Sold,marker='*',c='black') # company A
plt.xticks(rotation=90)
plt.ylabel('sales')
plt.show()

# %%
plt.figure(figsize=(10,5))
plt.title('Sales over a week')
plt.xlabel('products')
plt.plot(Product,Units_Sold1,marker='*',c='r') # company B
plt.xticks(rotation=90)
plt.ylabel('sales')
plt.show()

# %%
# This is so difficult to understand
# so, we compare these two graphs in one figure

# %%
plt.figure(figsize=(10,5))
plt.title('Sales over a week')
plt.xlabel('products')
plt.plot(Product,Units_Sold,marker='*',c='black') # A
plt.plot(Product,Units_Sold1,marker='o',c='r') # B
plt.xticks(rotation=90)
plt.ylabel('sales')
plt.show()

# %%
# in this is case we dont understand the plots in which company. so, we want legents to identify this.

# %%
plt.figure(figsize=(10,5))
plt.title('Sales over a week')
plt.xlabel('products')
plt.plot(Product,Units_Sold,marker='*',c='black')
plt.plot(Product,Units_Sold1,marker='o',c='r')
plt.legend(['A','B'])
plt.xticks(rotation=90)
plt.ylabel('sales')
plt.show()

# %%
oranges = [0.962, 0.941, 0.930, 0.923, 0.918, 0.908 ]
apples = [0.895, 0.91, 0.919, 0.926, 0.929, 0.931]
years = [2010, 2011, 2012, 2013, 2014, 2015]

# %%
plt.figure(figsize=(9,5))
plt.title('Year wise sales of oranges')
plt.xlabel('Years')
plt.ylabel('sales')
plt.plot(years,oranges,marker='o',color='g')
plt.legend('oranges')
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(9,5))
plt.title('Year wise sales of apples')
plt.xlabel('Years')
plt.ylabel('sales of apples')
plt.plot(years,apples,marker='s',c='yellow')
plt.legend('apples')
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(9,5))
plt.title('year wise sales of orange and apple')
plt.xlabel('Years')
plt.ylabel('sales')
plt.plot(years,oranges,marker='o',c='g')
plt.plot(years,apples,marker='s',c='yellow')
plt.legend(['oranges','apples'])
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ## Bar plot

# %%
Units_Sold1= [25, 40, 45, 50, 40, 25, 55]
Product= ['Product A', 'Product B', 'Product D', 'Product E', 'Product F', 'Product G', 'Product H']

# %%
plt.figure(figsize=(10,5))
plt.bar(Product,Units_Sold,color='pink')
plt.title('sales over a week',color='red')
plt.xlabel('products',color='blue')
plt.ylabel('sales',color='blue')
plt.xticks(rotation=90)
plt.grid(True)
plt.show()

# %% [markdown]
# ### horizontal bar plot

# %%
plt.figure(figsize=(10,5))
plt.barh(Product,Units_Sold,color='black')
plt.title('sales over a week',color='red')
plt.xlabel('sales',color='blue')
plt.ylabel('products',color='blue')
plt.grid(True,color='yellow')
plt.show()

# %%
x = ['Shirts', 'Pants','Shorts','Shoes']
y = [1000, 1200, 800, 1800]

# %%
plt.figure(figsize=(10,5))
plt.title('Price of outfit',color='g')
plt.bar(x,y,color='skyblue')
plt.xlabel('Dresses')
plt.ylabel('Rates')
plt.show()

# %% [markdown]
# ## Creating a dataframe using randint

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import random
np.random.seed(42)  # for reproducibility
data={
    'Age': np.random.randint(20,60,size=100),  # Randon ages b/w 20 and 60 
    'Salary': np.random.randint(30000,100000,size=100), # Random salary
    'YearsAtCompany': np.random.randint(1,20,size=100) # Random years at company
}

# %%
df=pd.DataFrame(data)

# %%
df
# Out:
#     Age  Salary  YearsAtCompany
# 0    58   65222              16
# 1    48   93335              16
# 2    34   40965              17
# 3    27   54538               2
# 4    40   38110               1
# ..  ...     ...             ...
# 95   28   77254              18
# 96   27   51918              13
# 97   31   90713               7
# 98   53   60306               4
# 99   52   46646              13
#
# [100 rows x 3 columns]

# %% [markdown]
# ## Histogram
#
# In statistics, it is essential to be aware of the distribution of continuous variables prior to running any type of analysis. To display the distribution, we will use a histogram. Histograms display the frequency by the bin for a given array

# %%
plt.hist(df['Age'],bins=10,color='pink',edgecolor='black')
plt.show()

# %%
plt.figure(figsize=(13,5))
plt.title('MONTHLY SALARY OF EMPLOYEES',color='b')
plt.xlabel('Salary of Employees',color='r')
plt.ylabel('No. of Employees',color='r')
plt.hist(df['Salary'],bins=20,color='g',edgecolor='black')
plt.show()

# %%
humidity={'humidity':np.random.randint(20,100,size=500)}

# %%
humidity=pd.DataFrame(humidity)

# %%
humidity
# Out:
#      humidity
# 0          39
# 1          84
# 2          27
# 3          35
# 4          33
# ..        ...
# 495        98
# 496        94
# 497        27
# 498        45
# 499        70
#
# [500 rows x 1 columns]

# %%
plt.figure(figsize=(10,5))
plt.title('HUMIDITY IN KERALA')
plt.hist(humidity,bins=10,color='pink',edgecolor='grey')
plt.xlabel('Humidity')
plt.show()

# %% [markdown]
# ## Boxplot

# %% [markdown]
# ![image.png](attachment:7a45314b-7dfc-4fc8-9585-cdda54bf0d8b.png)

# %% [markdown]
# * A boxplot is a standardized way of displaying the distribution of data based on a five number summary (“minimum”, first quartile (Q1), median, third quartile (Q3), and “maximum”).
# * It can tell you about your outliers and what their values are. It can also tell you if your data is symmetrical how tightly your data is grouped, and if and how your data is skewed.
# * The IQR (the range between Q1 and Q3) forms the box, showing the spread of the middle 50% of the data.
# * A smaller IQR indicates less variability in the central data, while a larger IQR suggests more spread in the middle values.

# %%
windspeed=[10, 15, 8, 20, 12, 0, 7, 14, 21, 18, 9, 6, 3, 11, 5, 13, 17, 19, 22, 16, 8, 10, 7, 5, 13]

# %%
plt.boxplot(windspeed)
plt.title('WIND DISTRIBUTION')
plt.show()

# %%
np.random.seed(42)
data = {
    'Category A': np.random.normal(50, 10, 100),  # Normal distribution, mean=50, std=10
    'Category B': np.random.normal(60, 20, 100),  # Normal distribution, mean=60, std=20
    'Category C': np.random.normal(55, 5, 100),   # Normal distribution, mean=55, std=5
    'Category D': np.append(np.random.normal(45, 10, 95), [100, 105, 110, 115, 120])  # Skewed with outliers
}

# %%
data=pd.DataFrame(data)

# %%
data
# Out:
#     Category A  Category B  Category C  Category D
# 0    54.967142   31.692585   56.788937   36.710050
# 1    48.617357   51.587094   57.803923   39.398190
# 2    56.476885   53.145710   60.415256   52.472936
# 3    65.230299   43.954455   60.269010   51.103703
# 4    47.658466   56.774286   48.111653   44.790984
# ..         ...         ...         ...         ...
# 95   35.364851   67.706348   51.535452  100.000000
# 96   52.961203   42.322851   59.497999  105.000000
# 97   52.610553   63.074502   56.536498  110.000000
# 98   50.051135   61.164174   59.064311  115.000000
# 99   47.654129   37.140594   58.148144  120.000000
#
# [100 rows x 4 columns]

# %%
plt.boxplot(data['Category A'])
plt.show()

# %%
plt.boxplot(data['Category B'])
plt.show()

# %%
plt.boxplot(data['Category C'])
plt.show()

# %%
plt.boxplot(data['Category D'])
plt.show()

# %%
plt.figure(figsize=(13,6))
plt.title('CATEGORY DISTRIBUTION')
plt.boxplot([data['Category A'],data['Category B'],data['Category C'],data['Category D']],labels=['A','B','C','D'])
plt.xlabel('Categories')
plt.ylabel('Distribution')
plt.show()

# %%
# Method 2
plt.figure(figsize=(13,5))
plt.boxplot(data,labels=['A','B','C','D'])
plt.show()

# %% [markdown]
# ## Violin Plot

# %% [markdown]
# * A violin plot is a hybrid of a box plot and a kernel density plot, which shows peaks in the data.
# * It is used to visualize the distribution of numerical data.
# * Unlike a box plot that can only show summary statistics, violin plots depict summary statistics and the density of each variable.

# %% [markdown]
# ![image.png](attachment:6c794227-be6d-4573-96dd-0cedf0cecb22.png)

# %%
plt.violinplot(windspeed)
plt.show()

# %% [markdown]
# ## Stacked Bar

# %%
data={
    'Quarter': ['Q1','Q2','Q3','Q4'],
    'Product A': [10,20,30,40],
    'Product B':[20,25,35,45],
    'Product c':[30,30,40,50]
    }
df=pd.DataFrame(data)

# %%
df
# Out:
#   Quarter  Product A  Product B  Product c
# 0      Q1         10         20         30
# 1      Q2         20         25         30
# 2      Q3         30         35         40
# 3      Q4         40         45         50

# %%
df.set_index('Quarter',inplace=True)

# %%
df.plot(kind='bar',stacked=True,colormap='viridis',xlabel='Quarter',ylabel='Sales',title='PRODUCT SALES OVER QUARTERS',figsize=(10,6));

# %% [markdown]
# ### Representing the number of units sold for different types of vehicles across three regions

# %%
data = {
    'Region': ['North', 'South', 'East', 'West'],
    'Sedans': [150, 200, 180, 220],
    'SUVs': [120, 180, 160, 200],
    'Trucks': [80, 100, 90, 120]
}

df = pd.DataFrame(data)

# %%
df
# Out:
#   Region  Sedans  SUVs  Trucks
# 0  North     150   120      80
# 1  South     200   180     100
# 2   East     180   160      90
# 3   West     220   200     120

# %%
df.set_index('Region',inplace=True)

# %%
df.plot(kind='bar',stacked=True,colormap='Reds',title='SALES OF VEHICLES ACROSS THREE REGIONS',xlabel='Region',ylabel='Sales',figsize=(10,6));

# %%
np.random.seed(42)
data={
    'Feature A':np.random.normal(loc=50,scale=10,size=1000),
    'Feature B':np.random.normal(loc=60,scale=15,size=1000),
    'Feature C':np.random.normal(loc=55,scale=5,size=1000),
    'Feature D':np.random.normal(loc=70,scale=15,size=1000)
}

# %%
df=pd.DataFrame(data)

# %%
df
# Out:
#      Feature A  Feature B  Feature C  Feature D
# 0    54.967142  80.990332  51.624109  41.382887
# 1    48.617357  73.869505  54.277407  57.094225
# 2    56.476885  60.894456  51.037900  63.795917
# 3    65.230299  50.295948  53.460192  98.315315
# 4    47.658466  70.473350  45.531927  78.348297
# ..         ...        ...        ...        ...
# 995  47.188997  76.052254  55.387403  70.426864
# 996  67.976865  59.602181  56.288763  38.832823
# 997  56.408429  46.771880  48.791197  65.195533
# 998  44.288210  57.553996  56.670882  94.650672
# 999  55.725828  48.826460  54.223705  75.409718
#
# [1000 rows x 4 columns]

# %%
df.plot(kind='hist',stacked=True,colormap='PuRd',figsize=(10,5),edgecolor='black');

# %%
df.hist(bins=10,color='g',edgecolor='black',grid=False)

plt.suptitle('histplot of data');

# %%
plt.figure(figsize=(15,8))
plt.violinplot(df)
plt.xlabel('Features')
plt.ylabel('Values')
plt.title('violin plot of features A,B,C and D')
plt.legend(df.columns)
plt.grid(False)
plt.show()

# %% [markdown]
# ## Scatter plot

# %% [markdown]
# * A scatter plot is a type of data visualization used to display the relationship between two numerical variables.
# * Each point on the plot represents an observation, with its position determined by the values of the two variables.
# * Scatter plots are useful for identifying trends, correlations, and patterns in data.

# %%
np.random.seed(42)
data={
    'Feature X':np.random.normal(loc=50,scale=10,size=100),
    'Feature Y':np.random.normal(loc=60,scale=15,size=100)
}

# %%
df=pd.DataFrame(data)

# %%
df
# Out:
#     Feature X  Feature Y
# 0   54.967142  38.769439
# 1   48.617357  53.690320
# 2   56.476885  54.859282
# 3   65.230299  47.965841
# 4   47.658466  57.580714
# ..        ...        ...
# 95  35.364851  65.779761
# 96  52.961203  46.742138
# 97  52.610553  62.305877
# 98  50.051135  60.873131
# 99  47.654129  42.855446
#
# [100 rows x 2 columns]

# %%
plt.figure(figsize=(10,5))
plt.scatter(df['Feature X'],df['Feature Y'],alpha=0.4,edgecolor='black')
plt.xlabel('Feature X')
plt.ylabel('Feature Y')
plt.title('scatter plot of features X and Y')
plt.grid(False)
plt.show()

# %%
data={
    'X':np.random.randint(25,100,size=200),
    'Y':np.random.randint(10,150,size=200)
}

# %%
df=pd.DataFrame(data)
df
# Out:
#       X    Y
# 0    26  131
# 1    41   14
# 2    57   38
# 3    33   92
# 4    67  145
# ..   ..  ...
# 195  64   56
# 196  66  136
# 197  33   65
# 198  74   23
# 199  51   37
#
# [200 rows x 2 columns]

# %%
plt.figure(figsize=(10,5))
plt.scatter(df['X'],df['Y'],alpha=0.6,edgecolor='black')
plt.title('SCATTER PLOT OF X AND Y')
plt.xlabel('X')
plt.ylabel('Y')
plt.show()

# %% [markdown]
# ## pie plot

# %%
Units_Sold1= [25, 40, 45, 50]
Product= ['Product A', 'Product B', 'Product D', 'Product E']

# %%
plt.pie(Units_Sold1,labels=Product,explode=(0,0,0,0.1),shadow=True,autopct="%1.2f%%",startangle=90)
plt.show()

# %%
data = {
      'season': [1, 1, 2, 2,1,3,2,3,2],
    'count': [16, 40, 32, 13,15,17,131,12,10]
}
df = pd.DataFrame(data)

# %%
df['season'].value_counts().plot(kind='pie',shadow=True,explode=(0,0,0.1),startangle=90,autopct="%1.1f%%");

# %% [markdown]
# ## Object-Oriented Approach Using Subplots

# %% [markdown]
# * In the object-oriented approach, we create a figure object that acts as an empty canvas and then we add a set of axes, or subplots, to it
# * Another advantage of using the object-oriented plotting approach is the ability to create multiple subplots on a single figure object.
# * In some situations, we want to compare different views of data side by side. We can accomplish this in Matplotlib using subplots

# %%
import numpy as np
x=np.linspace(0,10,20)

# %%
x
# Out:
# array([ 0.        ,  0.52631579,  1.05263158,  1.57894737,  2.10526316,
#         2.63157895,  3.15789474,  3.68421053,  4.21052632,  4.73684211,
#         5.26315789,  5.78947368,  6.31578947,  6.84210526,  7.36842105,
#         7.89473684,  8.42105263,  8.94736842,  9.47368421, 10.        ])

# %%
x2=x**2

# %%
x2
# Out:
# array([  0.        ,   0.27700831,   1.10803324,   2.49307479,
#          4.43213296,   6.92520776,   9.97229917,  13.5734072 ,
#         17.72853186,  22.43767313,  27.70083102,  33.51800554,
#         39.88919668,  46.81440443,  54.29362881,  62.32686981,
#         70.91412742,  80.05540166,  89.75069252, 100.        ])

# %%
x3=x**3

# %%
x3
# Out:
# array([0.00000000e+00, 1.45793847e-01, 1.16635078e+00, 3.93643388e+00,
#        9.33080624e+00, 1.82242309e+01, 3.14914711e+01, 5.00072897e+01,
#        7.46464499e+01, 1.06283715e+02, 1.45793847e+02, 1.94051611e+02,
#        2.51931768e+02, 3.20309083e+02, 4.00058318e+02, 4.92054235e+02,
#        5.97171599e+02, 7.16285173e+02, 8.50269719e+02, 1.00000000e+03])

# %%
fig, axes = plt.subplots(nrows=1, ncols=2)
axes[0].plot(x, x2)
axes[0].set_title('x by x Squared')
axes[0].set_xlabel('Linearly Spaced Numbers')
axes[0].set_ylabel('x2 Value')

axes[1].plot(x, x3)
axes[1].set_title('x by x cubed')
axes[1].set_xlabel('Linearly Spaced Numbers')
axes[1].set_ylabel('x3 Value')
plt.tight_layout()
plt.show()

# %%
a=np.random.randint(20,40,size=10)

# %%
a
# Out:
# array([33, 21, 32, 33, 38, 26, 22, 34, 33, 30])

# %%
a2=a**2

# %%
a2
# Out:
# array([1089,  441, 1024, 1089, 1444,  676,  484, 1156, 1089,  900])

# %%
a3=a**3

# %%
a3
# Out:
# array([35937,  9261, 32768, 35937, 54872, 17576, 10648, 39304, 35937,
#        27000], dtype=int32)

# %%
a4=a**4

# %%
a4
# Out:
# array([1185921,  194481, 1048576, 1185921, 2085136,  456976,  234256,
#        1336336, 1185921,  810000], dtype=int32)

# %%
a5=a**5

# %%
a5
# Out:
# array([39135393,  4084101, 33554432, 39135393, 79235168, 11881376,
#         5153632, 45435424, 39135393, 24300000], dtype=int32)

# %%
fig,axes=plt.subplots(nrows=2,ncols=2)

axes[0][0].bar(a,a2)
axes[0][0].set_title('square')
axes[0][0].set_xlabel('randomly created values')
axes[0][0].set_ylabel('a2 values')

axes[0][1].bar(a,a3)
axes[0][1].set_title('cube')
axes[0][1].set_xlabel('randomly created values')
axes[0][1].set_ylabel('a3 values')

axes[1][0].bar(a,a4)
axes[1][0].set_title(' fourth power')
axes[1][0].set_xlabel('randomly created values')
axes[1][0].set_ylabel(' a4 values')

axes[1][1].bar(a,a5)
axes[1][1].set_title('fifth power')
axes[1][1].set_xlabel('randomly created values')
axes[1][1].set_ylabel(' a5 values')

plt.tight_layout()
plt.show()
